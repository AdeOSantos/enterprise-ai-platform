# %% [markdown]
# # Data Exploration Notebook
#
# This notebook demonstrates data exploration and feature engineering.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load sample data
df = pd.read_csv('../../data/samples/sample_dataset.csv')
print(df.head())

# %%
# Basic statistics
df.describe()

# %%
# Visualization
df.hist(figsize=(10, 8))
plt.tight_layout()
plt.show()
